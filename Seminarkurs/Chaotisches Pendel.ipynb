# %% [markdown]
# # Projekt: Chaotisches Pendel simulieren
# - Name: Theodor Müller
# - Klasse: 12/3
# - Fach: Seminarkurs, Physik am Computer
#
# https://de.wikipedia.org/wiki/Doppelpendel

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

m1 = 0  # Masse
m2 = 0  # Masse
l1 = 0  # Länge
l2 = 0  # Länge
w1 = 0  # Auslenkung vom Lot
w2 = 0  # Auslenkung vom Lot

x1 = 0  # Ort
x2 = 0  # Ort
y1 = 0  # Höhe
y2 = 0  # Höhe


u1 = l1 * math.cos(math.radians(w1))
v1 = -l1 * math.cos(math.radians(w1))
